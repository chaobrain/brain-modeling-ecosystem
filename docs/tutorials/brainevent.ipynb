# %% [markdown]
# # Event-driven computations with ``brainevent``
#
# This placeholder page keeps the tutorial section buildable. Add the full brainevent walkthrough here when the package-specific tutorial is ready.
